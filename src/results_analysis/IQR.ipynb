# %% [markdown]
# # Modelo IQR

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Dataset Wind

# %%
# Replace 'your_file.npy' with the path to your .npy file
file_path = '../resultados_grid_search/Wind/Wind_IQR.npy'
data_wind = np.load(file_path)

# Define column names
columns = ['n_estimators', 'group_size', 'max_depth', 'MSE']

# Create a DataFrame
df_wind = pd.DataFrame(data_wind, columns=columns)

# %%
sorted_df_wind = df_wind.sort_values(by='MSE', ascending=True)
# sorted_df_wind['Rank'] = range(1, len(sorted_df_wind) + 1)

top_50_wind = sorted_df_wind[:50]
top_50_wind
# Out:
#       n_estimators  group_size  max_depth        MSE
# 2742          80.0         4.0       12.0  18.290495
# 2055          90.0         3.0       11.0  18.298008
# 4630          90.0         3.0       13.0  18.329262
# 918           90.0         3.0       15.0  18.336115
# 2594          90.0         3.0       30.0  18.364069
# 490           90.0         3.0       37.0  18.364069
# 3876          90.0         3.0       14.0  18.366604
# 740          600.0         3.0       15.0  18.383165
# 3392         600.0         3.0       11.0  18.386044
# 1072         450.0         3.0       11.0  18.401112
# 4697          90.0         3.0       22.0  18.405287
# 2809         100.0         5.0       12.0  18.415449
# 359          450.0         3.0       14.0  18.416296
# 42           270.0         3.0       21.0  18.419577
# 3958          60.0         3.0       13.0  18.425722
# 270          160.0         4.0       12.0  18.426180
# 3561         600.0         3.0       19.0  18.430275
# 1943          70.0         7.0       12.0  18.433216
# 1368         120.0         4.0       12.0  18.435003
# 2956        1050.0         3.0       11.0  18.435482
# 2341         600.0         3.0       31.0  18.436459
# 4721          80.0         8.0       11.0  18.436987
# 726          600.0         3.0       29.0  18.437313
# 4266         600.0         3.0       48.0  18.437704
# 1701         600.0         3.0       45.0  18.437704
# 323          600.0         3.0       33.0  18.437704
# 1028         600.0         3.0       46.0  18.437704
# 2713         600.0         3.0       44.0  18.437704
# 4272         600.0         3.0       40.0  18.437704
# 217          600.0         3.0       37.0  18.437704
# 3565         210.0         3.0       19.0  18.438345
# 159          600.0         3.0       18.0  18.438480
# 4142         600.0         3.0       17.0  18.440435
# 3264         900.0         3.0       11.0  18.441008
# 1468         450.0         3.0       17.0  18.441307
# 1843         750.0         3.0       15.0  18.441402
# 513          240.0         3.0       19.0  18.441708
# 4484         600.0         3.0       27.0  18.441841
# 1529          90.0        10.0       12.0  18.442007
# 2892         180.0         3.0       16.0  18.444389
# 3495         270.0         3.0       50.0  18.448160
# 2723         270.0         3.0       47.0  18.448160
# 1518         270.0         3.0       32.0  18.448160
# 4797         270.0         3.0       34.0  18.448160
# 2837        1050.0         3.0       15.0  18.450912
# 3252         450.0         3.0       20.0  18.453577
# 3091         450.0         3.0       25.0  18.454103
# 297          300.0         3.0       21.0  18.454958
# 3710         450.0         3.0       31.0  18.456556
# 4552         450.0         3.0       27.0  18.457760

# %% [markdown]
# ## Dataset Carbon Emission

# %%
file_path = '../resultados_grid_search/Carbon_Emission/Carbon_Emission_IQR.npy'
data_carbon = np.load(file_path)

# Define column names
columns = ['n_estimators', 'group_size', 'max_depth', 'MSE']

# Create a DataFrame
df_carbon = pd.DataFrame(data_carbon, columns=columns)

# %%
sorted_df_carbon = df_carbon.sort_values(by='MSE', ascending=True)
# sorted_df_carbon['Rank'] = range(1, len(sorted_df_carbon) + 1)

top_50_carbon = sorted_df_carbon[:50]
top_50_carbon
# Out:
#       n_estimators  group_size  max_depth            MSE
# 4856         150.0         3.0       17.0  260131.968750
# 4226         160.0        40.0       17.0  260376.375000
# 561          180.0         3.0       17.0  260562.484375
# 1209         160.0         5.0       20.0  260881.406250
# 602          140.0        35.0       17.0  261093.500000
# 204          180.0        45.0       20.0  261126.375000
# 887          170.0         5.0       20.0  261277.203125
# 1446         160.0         4.0       17.0  261459.046875
# 3264         140.0        20.0       17.0  261468.531250
# 1028         140.0         5.0       20.0  261508.421875
# 4502         160.0        10.0       19.0  261631.937500
# 853          210.0         5.0       20.0  261732.859375
# 4213         150.0         5.0       17.0  261794.015625
# 2718         150.0         3.0       50.0  261806.078125
# 1464         150.0         3.0       43.0  261806.078125
# 3275         150.0         3.0       47.0  261806.078125
# 2748         150.0         3.0       36.0  261806.078125
# 2723         150.0         3.0       41.0  261806.078125
# 3491         180.0         3.0       24.0  261824.750000
# 3064         240.0         3.0       19.0  261897.796875
# 2596         180.0         3.0       48.0  261930.937500
# 2550         180.0         3.0       43.0  261930.937500
# 2510         180.0         3.0       41.0  261930.937500
# 1210         180.0         3.0       32.0  261930.937500
# 956          180.0         3.0       33.0  261930.937500
# 1636         180.0         3.0       31.0  261930.937500
# 2404         180.0         3.0       35.0  261930.937500
# 1688         230.0         5.0       20.0  261936.125000
# 4334         180.0        15.0       19.0  262015.078125
# 2345         200.0         5.0       20.0  262070.468750
# 752          180.0        45.0       19.0  262076.125000
# 2388         160.0         4.0       20.0  262169.406250
# 2749         300.0         3.0       20.0  262185.531250
# 16           170.0        10.0       19.0  262186.156250
# 610          160.0        10.0       17.0  262249.656250
# 3731         250.0        10.0       19.0  262315.062500
# 2107         180.0        45.0       16.0  262338.656250
# 921          260.0         5.0       20.0  262339.375000
# 1985         150.0         3.0       19.0  262341.656250
# 2456         180.0         3.0       16.0  262343.250000
# 258          130.0         5.0       20.0  262387.718750
# 737          270.0         3.0       19.0  262390.093750
# 1708         180.0        20.0       20.0  262396.531250
# 2313         190.0        10.0       19.0  262407.281250
# 2684         450.0         3.0       20.0  262545.812500
# 428          180.0         6.0       20.0  262548.781250
# 777          270.0         3.0       18.0  262556.625000
# 2334         210.0         7.0       20.0  262578.718750
# 1684         210.0         3.0       21.0  262647.531250
# 2250         180.0         3.0       15.0  262659.500000

# %% [markdown]
# ## House 8L

# %%
file_path = '../resultados_grid_search/House_8L/House_8L_IQR.npy'
data_house_8L = np.load(file_path)

# Define column names
columns = ['n_estimators', 'group_size', 'max_depth', 'MSE']

# Create a DataFrame
df_house_8L = pd.DataFrame(data_house_8L, columns=columns)

# %%
sorted_df_house_8L = df_house_8L.sort_values(by='MSE', ascending=True)
# sorted_df_house_8L['Rank'] = range(1, len(sorted_df_house_8L) + 1)

top_50_house_8L = sorted_df_house_8L[:50]
top_50_house_8L
# Out:
#       n_estimators  group_size  max_depth          MSE
# 1129        2250.0         3.0       27.0  948657280.0
# 155         2250.0         3.0       28.0  949179136.0
# 4020        2250.0         3.0       32.0  949267072.0
# 2574        3750.0         3.0       41.0  949372544.0
# 4593        3750.0         3.0       45.0  949372544.0
# 142         3750.0         3.0       42.0  949372544.0
# 816         3750.0         3.0       46.0  949372544.0
# 898         3750.0         3.0       38.0  949405056.0
# 1518        2250.0         3.0       34.0  949449024.0
# 3427        2250.0         3.0       33.0  949459200.0
# 1735        2250.0         3.0       48.0  949467520.0
# 3494        2250.0         3.0       50.0  949467520.0
# 3473        2250.0         3.0       44.0  949467520.0
# 4991        2250.0         3.0       42.0  949467520.0
# 3038        3750.0         3.0       29.0  949682944.0
# 2907        3500.0         4.0       41.0  949984448.0
# 204         3500.0         4.0       47.0  949984448.0
# 3397        3500.0         4.0       46.0  949984448.0
# 4983        3500.0         4.0       37.0  950027136.0
# 19          3500.0         4.0       33.0  950099456.0
# 1682        3750.0         3.0       21.0  950218624.0
# 2716         600.0         3.0       27.0  950305536.0
# 3043        3000.0         3.0       39.0  950454144.0
# 4860        3000.0         3.0       34.0  950465280.0
# 1468        3000.0         3.0       50.0  950466368.0
# 4257        3000.0         3.0       36.0  950474816.0
# 911         2250.0         3.0       22.0  950478016.0
# 1903         160.0         4.0       38.0  950637312.0
# 3334         160.0         4.0       40.0  950637312.0
# 603          160.0         4.0       45.0  950637312.0
# 2068         160.0         4.0       43.0  950637312.0
# 4963         160.0         4.0       49.0  950637312.0
# 3984         160.0         4.0       41.0  950637312.0
# 1990        3000.0         4.0       32.0  950857728.0
# 3631        2500.0         4.0       29.0  951044160.0
# 1057        3750.0         3.0       19.0  951092416.0
# 4270        2500.0         4.0       23.0  951121536.0
# 3111        3000.0         4.0        NaN  951171904.0
# 790         3000.0         4.0       49.0  951171904.0
# 2253        3000.0         4.0       50.0  951171904.0
# 2920        3000.0         4.0       38.0  951195520.0
# 921         2500.0         4.0       49.0  951224832.0
# 2801        2500.0         4.0        NaN  951224832.0
# 4065         160.0         4.0       34.0  951246464.0
# 1392        2000.0         4.0       32.0  951253312.0
# 4202        2500.0         4.0       38.0  951253568.0
# 181         2500.0         4.0       37.0  951260992.0
# 4000        1650.0         3.0       28.0  951275264.0
# 2114        3000.0         3.0       20.0  951312768.0
# 172         2500.0         4.0       35.0  951335296.0

# %%
# Drop the 'MSE' column from each top_50 DataFrame
top_50_wind_dropped = top_50_wind.drop(columns=['MSE'])
top_50_carbon_dropped = top_50_carbon.drop(columns=['MSE'])
top_50_house_8L_dropped = top_50_house_8L.drop(columns=['MSE'])

# Concatenate the DataFrames
concatenated_df = pd.concat([top_50_carbon_dropped, top_50_house_8L_dropped, top_50_wind_dropped], ignore_index=True)

# Drop repeated rows
concatenated_df = concatenated_df.drop_duplicates()

# Save the concatenated DataFrame to a CSV file
concatenated_df.to_csv('csvs/IQR_Top_150.csv', index=False)
