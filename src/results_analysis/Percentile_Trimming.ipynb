# %% [markdown]
# # Modelo Percentile Trimming

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Dataset Wind

# %%
# Replace 'your_file.npy' with the path to your .npy file
file_path = '../resultados_grid_search/Wind/Wind_Percentile_Trimming.npy'
data_wind = np.load(file_path)

# Define column names
columns = ['n_estimators', 'group_size', 'max_depth', 'percentile', 'MSE']

# Create a DataFrame
df_wind = pd.DataFrame(data_wind, columns=columns)

# %%
sorted_df_wind = df_wind.sort_values(by='MSE', ascending=True)

top_50_wind = sorted_df_wind[:50]
top_50_wind
# Out:
#       n_estimators  group_size  max_depth  percentile        MSE
# 1779          80.0        10.0       12.0        11.0  18.346655
# 1128          90.0        30.0       12.0         3.0  18.356337
# 1914          80.0        40.0       12.0         7.0  18.363653
# 2166          80.0         5.0       12.0         1.0  18.393511
# 618          100.0        10.0       12.0         2.0  18.420267
# 1585          90.0         6.0       12.0         7.0  18.420631
# 66            90.0        30.0       12.0         5.0  18.431595
# 785          100.0         5.0       12.0         1.0  18.448273
# 1999          80.0        40.0       18.0         1.0  18.453564
# 1493          80.0         4.0       11.0        10.0  18.456320
# 536          120.0        40.0       12.0         1.0  18.464418
# 1610          60.0         4.0       12.0         9.0  18.465332
# 970           80.0         8.0       11.0         2.0  18.466066
# 1989         270.0        15.0       12.0         5.0  18.471918
# 2235         180.0         4.0       12.0        12.0  18.475313
# 27            80.0        40.0       45.0         2.0  18.483166
# 313           90.0        45.0       19.0         4.0  18.505119
# 1351        1250.0        50.0       11.0         2.0  18.509218
# 2064          80.0        20.0       15.0         3.0  18.509499
# 2430         300.0        50.0       14.0         1.0  18.509958
# 392          180.0         9.0       12.0         9.0  18.512207
# 1042         110.0         5.0       12.0         1.0  18.515350
# 1616         500.0        20.0       12.0         1.0  18.515837
# 1033         120.0         4.0       12.0         4.0  18.516563
# 1499         100.0        20.0       19.0         1.0  18.517008
# 1856         240.0         4.0       12.0         1.0  18.517103
# 1380         300.0        50.0       22.0         2.0  18.517113
# 849          280.0        10.0       12.0        11.0  18.517145
# 1710         280.0        10.0       12.0        10.0  18.517145
# 2103         650.0         5.0       12.0         7.0  18.520279
# 944          240.0         5.0       12.0         5.0  18.524330
# 436          600.0        50.0       39.0         1.0  18.524731
# 2020         200.0         4.0       12.0        10.0  18.525005
# 2444         200.0         4.0       12.0         1.0  18.525005
# 310          200.0         4.0       12.0        12.0  18.525005
# 1415         450.0        45.0       19.0         1.0  18.527983
# 1486         280.0        40.0       12.0         4.0  18.529797
# 846          280.0         4.0       12.0         2.0  18.530037
# 1443         280.0        20.0       11.0         5.0  18.531174
# 651           80.0         5.0       11.0         5.0  18.533377
# 2097          80.0         5.0       11.0         4.0  18.533377
# 1719         900.0        20.0       12.0         4.0  18.534433
# 564           90.0         6.0       11.0        15.0  18.534948
# 1073         280.0        40.0       17.0         1.0  18.535452
# 679           90.0         5.0       11.0        10.0  18.537085
# 1261          90.0         5.0       11.0         8.0  18.537085
# 107          120.0         5.0       12.0         6.0  18.538301
# 474          150.0        50.0       14.0         2.0  18.540901
# 40           250.0        50.0       45.0         2.0  18.542751
# 399           80.0        20.0       10.0         5.0  18.543259

# %% [markdown]
# ## Dataset Carbon Emission

# %%
file_path = '../resultados_grid_search/Carbon_Emission/Carbon_Emission_Percentile_Trimming.npy'
data_carbon = np.load(file_path)

# Define column names
columns = ['n_estimators', 'group_size', 'max_depth', 'percentile', 'MSE']

# Create a DataFrame
df_carbon = pd.DataFrame(data_carbon, columns=columns)

# %%
sorted_df_carbon = df_carbon.sort_values(by='MSE', ascending=True)

top_50_carbon = sorted_df_carbon[:50]
top_50_carbon
# Out:
#       n_estimators  group_size  max_depth  percentile            MSE
# 983          150.0        15.0       17.0         3.0  260283.671875
# 74           150.0        50.0       44.0         1.0  261205.500000
# 69           150.0        50.0       34.0         2.0  261205.500000
# 1749         180.0        45.0       29.0         2.0  261301.765625
# 1271         140.0        35.0       21.0         1.0  261792.140625
# 269          180.0        30.0       20.0         4.0  261811.078125
# 835          210.0        35.0       20.0         3.0  261971.265625
# 1974         180.0         9.0       17.0        12.0  261982.718750
# 783           90.0        45.0       20.0         2.0  262048.140625
# 2382         180.0        30.0       41.0         3.0  262085.265625
# 1029         350.0        50.0       17.0         2.0  262153.000000
# 2052         170.0         5.0       20.0        10.0  262181.687500
# 895          150.0        30.0       23.0         3.0  262258.343750
# 2036         180.0        45.0       36.0         3.0  262278.468750
# 143          150.0        25.0       18.0         4.0  262283.718750
# 279          250.0        50.0       31.0         2.0  262286.593750
# 1011         160.0         5.0       17.0         7.0  262287.156250
# 696          450.0        45.0       20.0         2.0  262343.718750
# 728          180.0        30.0       14.0         3.0  262360.593750
# 1713         200.0        25.0       18.0         4.0  262371.000000
# 2262         160.0        10.0       20.0         5.0  262422.843750
# 2306         140.0        35.0       43.0         1.0  262448.593750
# 453          170.0        10.0       20.0         2.0  262483.718750
# 1764         150.0        50.0       40.0         4.0  262506.593750
# 722          400.0        50.0       14.0         1.0  262615.062500
# 327          160.0        40.0       45.0         5.0  262659.843750
# 1339         160.0        10.0       19.0         2.0  262692.437500
# 380          250.0        50.0       18.0         4.0  262765.031250
# 277          250.0        50.0       22.0         1.0  262804.875000
# 643          150.0        15.0       21.0         3.0  262805.593750
# 428          180.0        20.0       40.0         4.0  262859.281250
# 164          180.0        20.0       46.0         1.0  262859.281250
# 464          180.0        20.0       45.0         3.0  262859.281250
# 7            350.0        35.0       18.0         1.0  262868.625000
# 2171         450.0        50.0       20.0         4.0  262890.906250
# 1467         150.0        25.0       20.0        10.0  262898.093750
# 1319         280.0        40.0       19.0         5.0  262904.500000
# 669          180.0         4.0       20.0        14.0  262907.750000
# 642          180.0         4.0       20.0         4.0  262907.750000
# 1505         280.0         8.0       19.0        13.0  262916.031250
# 2054         280.0        20.0       19.0         2.0  262964.312500
# 715          400.0        40.0       19.0         1.0  262971.312500
# 1799         180.0         3.0       49.0        10.0  262978.593750
# 1289         180.0         3.0       29.0        14.0  262978.593750
# 1542         180.0         3.0       45.0         1.0  262978.593750
# 2089         180.0         3.0       44.0        10.0  262978.593750
# 1921         180.0        15.0       48.0         6.0  262991.156250
# 1446         180.0        15.0       49.0         6.0  262991.156250
# 1769         160.0        20.0       35.0         2.0  262996.125000
# 1880         160.0        20.0       26.0         1.0  262996.125000

# %% [markdown]
# ## House 8L

# %%
file_path = '../resultados_grid_search/House_8L/House_8L_Percentile_Trimming.npy'
data_house_8L = np.load(file_path)

# Define column names
columns = ['n_estimators', 'group_size', 'max_depth', 'percentile', 'MSE']

# Create a DataFrame
df_house_8L = pd.DataFrame(data_house_8L, columns=columns)

# %%
sorted_df_house_8L = df_house_8L.sort_values(by='MSE', ascending=True)

top_50_house_8L = sorted_df_house_8L[:50]
top_50_house_8L
# Out:
#       n_estimators  group_size  max_depth  percentile          MSE
# 1256         700.0        25.0       27.0         1.0  947866688.0
# 556          140.0        35.0       37.0         4.0  947942912.0
# 982          650.0        50.0       27.0         2.0  948147520.0
# 626          700.0        20.0       22.0         4.0  948198464.0
# 683          140.0        20.0       44.0         5.0  948939520.0
# 1182         400.0        20.0       21.0         1.0  949810304.0
# 855          850.0        25.0       28.0         4.0  949970304.0
# 962          700.0        50.0       22.0         5.0  950069120.0
# 1291         450.0        30.0       21.0         3.0  950136896.0
# 1133         350.0        50.0       23.0         3.0  950155648.0
# 2176         160.0        20.0       35.0         3.0  950287872.0
# 162          150.0        25.0       44.0         6.0  950315456.0
# 973          160.0        20.0       38.0         3.0  950389952.0
# 1429        1500.0        20.0       29.0         3.0  950496512.0
# 2262         700.0        20.0       36.0         2.0  950503680.0
# 2039         700.0        50.0       19.0         4.0  950675648.0
# 721          350.0        25.0       23.0         4.0  950933568.0
# 1175         450.0        15.0       23.0         1.0  950960384.0
# 220          180.0        20.0       49.0         1.0  951034816.0
# 1393         900.0        20.0       25.0         3.0  951095744.0
# 49           600.0        15.0       32.0         6.0  951113408.0
# 1403         850.0        25.0       23.0         4.0  951157504.0
# 389          900.0        45.0       32.0         2.0  951189056.0
# 1816        1500.0        25.0       28.0         4.0  951209152.0
# 1573         750.0        50.0       32.0         3.0  951232000.0
# 568          850.0        25.0       32.0         4.0  951294208.0
# 589          900.0        30.0       21.0         2.0  951340928.0
# 1889         180.0        20.0       33.0         2.0  951430080.0
# 2420         180.0        45.0       45.0         1.0  951455808.0
# 1519         600.0        40.0       27.0         8.0  951475776.0
# 356          400.0        20.0       22.0         1.0  951522688.0
# 782          700.0        35.0       35.0         2.0  951530880.0
# 1589         900.0        45.0       29.0         3.0  951535104.0
# 1738         120.0        40.0       32.0         2.0  951563968.0
# 278          140.0        10.0       32.0         4.0  951577280.0
# 354          700.0        35.0       19.0         3.0  951599808.0
# 838          800.0        50.0       27.0         1.0  951626688.0
# 1451         500.0        25.0       22.0         3.0  951675584.0
# 1883         600.0        50.0       21.0         2.0  951680256.0
# 2015         400.0        20.0       44.0         1.0  951694912.0
# 1562         600.0        15.0       23.0         1.0  951711680.0
# 875          900.0        20.0       37.0         2.0  951780416.0
# 2170         700.0        25.0       28.0         3.0  951801984.0
# 745          450.0        50.0       22.0         3.0  951819392.0
# 2168         900.0        20.0       45.0         5.0  951842752.0
# 2323         900.0        20.0       39.0         1.0  951842752.0
# 1579         900.0        20.0       46.0         4.0  951842752.0
# 878          900.0        20.0       39.0         4.0  951842752.0
# 229          150.0        50.0       37.0         5.0  951899008.0
# 2162         150.0        50.0       46.0         6.0  951899008.0

# %%
# Drop the 'MSE' column from each top_50 DataFrame
top_50_wind_dropped = top_50_wind.drop(columns=['MSE'])
top_50_carbon_dropped = top_50_carbon.drop(columns=['MSE'])
top_50_house_8L_dropped = top_50_house_8L.drop(columns=['MSE'])

# Concatenate the DataFrames
concatenated_df = pd.concat([top_50_carbon_dropped, top_50_house_8L_dropped, top_50_wind_dropped], ignore_index=True)

# Drop repeated rows
concatenated_df = concatenated_df.drop_duplicates()

# Convert all values to integers
concatenated_df = concatenated_df.astype(int)

# Save the concatenated DataFrame to a CSV file
concatenated_df.to_csv('csvs/Percentile_Trimming_Top_150.csv', index=False)

# %% [markdown]
# # Top 150

# %%
file_path = '../resultados_top_150/Wind/Wind_Percentile_Trimming_150.npy'
data_wind = np.load(file_path)

# Define column names
columns = ['n_estimators', 'group_size', 'max_depth', 'percentile', 'MSE']

df_wind_150 = pd.DataFrame(data_wind, columns=columns)

sorted_df_wind_150 = df_wind_150.sort_values(by='MSE', ascending=True)

# Add rank column
sorted_df_wind_150['rank'] = sorted_df_wind_150['MSE'].rank(method='min')

sorted_df_wind_150[50:100]
# Out:
#      n_estimators  group_size  max_depth  percentile        MSE   rank
# 15          250.0        50.0       31.0         2.0  18.542751   51.0
# 148         250.0        50.0       45.0         2.0  18.542751   51.0
# 149          80.0        20.0       10.0         5.0  18.543259   53.0
# 24          400.0        50.0       14.0         1.0  18.549532   54.0
# 52          650.0        50.0       27.0         2.0  18.553936   55.0
# 8            90.0        45.0       20.0         2.0  18.557732   56.0
# 18          180.0        30.0       14.0         3.0  18.559910   57.0
# 10          350.0        50.0       17.0         2.0  18.576759   58.0
# 17          450.0        45.0       20.0         2.0  18.584833   59.0
# 58          450.0        30.0       21.0         3.0  18.589647   60.0
# 41          400.0        40.0       19.0         1.0  18.596130   61.0
# 40          280.0        20.0       19.0         2.0  18.598419   62.0
# 36          280.0        40.0       19.0         5.0  18.607016   63.0
# 81          700.0        35.0       35.0         2.0  18.607710   64.0
# 3           180.0        45.0       29.0         2.0  18.608484   65.0
# 72          900.0        45.0       32.0         2.0  18.608686   66.0
# 87          500.0        25.0       22.0         3.0  18.608864   67.0
# 86          800.0        50.0       27.0         1.0  18.614199   68.0
# 78          180.0        45.0       45.0         1.0  18.620199   69.0
# 76          900.0        30.0       21.0         2.0  18.623480   70.0
# 93          450.0        50.0       22.0         3.0  18.629328   71.0
# 83          120.0        40.0       32.0         2.0  18.638313   72.0
# 2           150.0        50.0       34.0         2.0  18.639444   73.0
# 1           150.0        50.0       44.0         1.0  18.642565   74.0
# 92          700.0        25.0       28.0         3.0  18.643595   75.0
# 65          700.0        50.0       19.0         4.0  18.651855   76.0
# 21          140.0        35.0       43.0         1.0  18.656092   77.0
# 53          700.0        20.0       22.0         4.0  18.658966   78.0
# 50          700.0        25.0       27.0         1.0  18.659012   79.0
# 56          850.0        25.0       28.0         4.0  18.664429   80.0
# 34          450.0        50.0       20.0         4.0  18.666700   81.0
# 75          850.0        25.0       32.0         4.0  18.668661   82.0
# 64          700.0        20.0       36.0         2.0  18.668900   83.0
# 70          600.0        15.0       32.0         6.0  18.671724   84.0
# 33          350.0        35.0       18.0         1.0  18.674709   85.0
# 80          400.0        20.0       22.0         1.0  18.677443   86.0
# 4           140.0        35.0       21.0         1.0  18.678833   87.0
# 9           180.0        30.0       41.0         3.0  18.686705   88.0
# 96          900.0        20.0       46.0         4.0  18.690531   89.0
# 94          900.0        20.0       45.0         5.0  18.690531   89.0
# 97          900.0        20.0       39.0         4.0  18.690531   89.0
# 91          900.0        20.0       37.0         2.0  18.693113   92.0
# 95          900.0        20.0       39.0         1.0  18.693113   92.0
# 73         1500.0        25.0       28.0         4.0  18.693535   94.0
# 32          180.0        20.0       45.0         3.0  18.694168   95.0
# 30          180.0        20.0       40.0         4.0  18.694168   95.0
# 74          750.0        50.0       32.0         3.0  18.694614   97.0
# 69          900.0        20.0       25.0         3.0  18.694614   97.0
# 27          250.0        50.0       18.0         4.0  18.697643   99.0
# 71          850.0        25.0       23.0         4.0  18.697678  100.0

# %%
file_path = '../resultados_top_150/House_8L/House_8L_Percentile_Trimming_150.npy'
data_house = np.load(file_path)

# Define column names
columns = ['n_estimators', 'group_size', 'max_features', 'percentile', 'MSE']

df_house_150 = pd.DataFrame(data_house, columns=columns)

sorted_df_house_150 = df_house_150.sort_values(by='MSE', ascending=True)

# Add rank column
sorted_df_house_150['rank'] = sorted_df_house_150['MSE'].rank(method='min')

sorted_df_house_150[:50]
# Out:
#     n_estimators  group_size  max_features  percentile          MSE  rank
# 50         700.0        25.0          27.0         1.0  947866688.0   1.0
# 51         140.0        35.0          37.0         4.0  947942912.0   2.0
# 52         650.0        50.0          27.0         2.0  948147520.0   3.0
# 53         700.0        20.0          22.0         4.0  948198464.0   4.0
# 54         140.0        20.0          44.0         5.0  948939520.0   5.0
# 21         140.0        35.0          43.0         1.0  949136768.0   6.0
# 55         400.0        20.0          21.0         1.0  949810304.0   7.0
# 23         150.0        50.0          40.0         4.0  949900672.0   8.0
# 56         850.0        25.0          28.0         4.0  949970304.0   9.0
# 1          150.0        50.0          44.0         1.0  950025152.0  10.0
# 2          150.0        50.0          34.0         2.0  950025152.0  10.0
# 57         700.0        50.0          22.0         5.0  950069120.0  12.0
# 58         450.0        30.0          21.0         3.0  950136896.0  13.0
# 59         350.0        50.0          23.0         3.0  950155648.0  14.0
# 60         160.0        20.0          35.0         3.0  950287872.0  15.0
# 48         160.0        20.0          35.0         2.0  950287872.0  15.0
# 61         150.0        25.0          44.0         6.0  950315456.0  17.0
# 62         160.0        20.0          38.0         3.0  950389952.0  18.0
# 63        1500.0        20.0          29.0         3.0  950496512.0  19.0
# 64         700.0        20.0          36.0         2.0  950503680.0  20.0
# 65         700.0        50.0          19.0         4.0  950675648.0  21.0
# 17         450.0        45.0          20.0         2.0  950706240.0  22.0
# 28         250.0        50.0          22.0         1.0  950802944.0  23.0
# 13         180.0        45.0          36.0         3.0  950873088.0  24.0
# 66         350.0        25.0          23.0         4.0  950933568.0  25.0
# 67         450.0        15.0          23.0         1.0  950960384.0  26.0
# 32         180.0        20.0          45.0         3.0  951034816.0  27.0
# 68         180.0        20.0          49.0         1.0  951034816.0  27.0
# 31         180.0        20.0          46.0         1.0  951034816.0  27.0
# 30         180.0        20.0          40.0         4.0  951034816.0  27.0
# 69         900.0        20.0          25.0         3.0  951095744.0  31.0
# 70         600.0        15.0          32.0         6.0  951113408.0  32.0
# 71         850.0        25.0          23.0         4.0  951157504.0  33.0
# 72         900.0        45.0          32.0         2.0  951189056.0  34.0
# 73        1500.0        25.0          28.0         4.0  951209152.0  35.0
# 74         750.0        50.0          32.0         3.0  951232000.0  36.0
# 75         850.0        25.0          32.0         4.0  951294208.0  37.0
# 76         900.0        30.0          21.0         2.0  951340928.0  38.0
# 77         180.0        20.0          33.0         2.0  951430080.0  39.0
# 78         180.0        45.0          45.0         1.0  951455808.0  40.0
# 79         600.0        40.0          27.0         8.0  951475776.0  41.0
# 80         400.0        20.0          22.0         1.0  951522688.0  42.0
# 81         700.0        35.0          35.0         2.0  951530880.0  43.0
# 82         900.0        45.0          29.0         3.0  951535104.0  44.0
# 83         120.0        40.0          32.0         2.0  951563968.0  45.0
# 84         140.0        10.0          32.0         4.0  951577280.0  46.0
# 85         700.0        35.0          19.0         3.0  951599808.0  47.0
# 86         800.0        50.0          27.0         1.0  951626688.0  48.0
# 87         500.0        25.0          22.0         3.0  951675584.0  49.0
# 88         600.0        50.0          21.0         2.0  951680256.0  50.0

# %%
file_path = '../resultados_top_150/Carbon_Emission/Carbon_Emission_Percentile_Trimming_150.npy'
data_carbon = np.load(file_path)

# Define column names
columns = ['n_estimators', 'group_size', 'max_depth', 'percentile', 'MSE']

df_carbon_150 = pd.DataFrame(data_carbon, columns=columns)

sorted_df_carbon_150 = df_carbon_150.sort_values(by='MSE', ascending=True)

# Add rank column
sorted_df_carbon_150['rank'] = sorted_df_carbon_150['MSE'].rank(method='min')

sorted_df_carbon_150[:50]
# Out:
#      n_estimators  group_size  max_depth  percentile            MSE  rank
# 0           150.0        15.0       17.0         3.0  260283.671875   1.0
# 1           150.0        50.0       44.0         1.0  261205.500000   2.0
# 2           150.0        50.0       34.0         2.0  261205.500000   2.0
# 3           180.0        45.0       29.0         2.0  261301.765625   4.0
# 78          180.0        45.0       45.0         1.0  261301.765625   4.0
# 143         280.0        40.0       17.0         1.0  261650.015625   6.0
# 4           140.0        35.0       21.0         1.0  261792.140625   7.0
# 5           180.0        30.0       20.0         4.0  261811.078125   8.0
# 6           210.0        35.0       20.0         3.0  261971.265625   9.0
# 7           180.0         9.0       17.0        12.0  261982.718750  10.0
# 8            90.0        45.0       20.0         2.0  262048.140625  11.0
# 9           180.0        30.0       41.0         3.0  262085.265625  12.0
# 10          350.0        50.0       17.0         2.0  262153.000000  13.0
# 11          170.0         5.0       20.0        10.0  262181.687500  14.0
# 12          150.0        30.0       23.0         3.0  262258.343750  15.0
# 13          180.0        45.0       36.0         3.0  262278.468750  16.0
# 14          150.0        25.0       18.0         4.0  262283.718750  17.0
# 15          250.0        50.0       31.0         2.0  262286.593750  18.0
# 148         250.0        50.0       45.0         2.0  262286.593750  18.0
# 16          160.0         5.0       17.0         7.0  262287.156250  20.0
# 17          450.0        45.0       20.0         2.0  262343.718750  21.0
# 18          180.0        30.0       14.0         3.0  262360.593750  22.0
# 19          200.0        25.0       18.0         4.0  262371.000000  23.0
# 20          160.0        10.0       20.0         5.0  262422.843750  24.0
# 147         150.0        50.0       14.0         2.0  262424.343750  25.0
# 21          140.0        35.0       43.0         1.0  262448.593750  26.0
# 22          170.0        10.0       20.0         2.0  262483.718750  27.0
# 23          150.0        50.0       40.0         4.0  262506.593750  28.0
# 24          400.0        50.0       14.0         1.0  262615.062500  29.0
# 25          160.0        40.0       45.0         5.0  262659.843750  30.0
# 26          160.0        10.0       19.0         2.0  262692.437500  31.0
# 27          250.0        50.0       18.0         4.0  262765.031250  32.0
# 28          250.0        50.0       22.0         1.0  262804.875000  33.0
# 29          150.0        15.0       21.0         3.0  262805.593750  34.0
# 32          180.0        20.0       45.0         3.0  262859.281250  35.0
# 31          180.0        20.0       46.0         1.0  262859.281250  35.0
# 68          180.0        20.0       49.0         1.0  262859.281250  35.0
# 77          180.0        20.0       33.0         2.0  262859.281250  35.0
# 30          180.0        20.0       40.0         4.0  262859.281250  35.0
# 33          350.0        35.0       18.0         1.0  262868.625000  40.0
# 34          450.0        50.0       20.0         4.0  262890.906250  41.0
# 35          150.0        25.0       20.0        10.0  262898.093750  42.0
# 36          280.0        40.0       19.0         5.0  262904.500000  43.0
# 38          180.0         4.0       20.0         4.0  262907.750000  44.0
# 37          180.0         4.0       20.0        14.0  262907.750000  44.0
# 39          280.0         8.0       19.0        13.0  262916.031250  46.0
# 40          280.0        20.0       19.0         2.0  262964.312500  47.0
# 41          400.0        40.0       19.0         1.0  262971.312500  48.0
# 45          180.0         3.0       44.0        10.0  262978.593750  49.0
# 44          180.0         3.0       45.0         1.0  262978.593750  49.0
