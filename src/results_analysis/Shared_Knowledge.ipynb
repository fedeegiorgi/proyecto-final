# %% [markdown]
# # Modelo Percentile Trimming

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Dataset Wind

# %%
# Replace 'your_file.npy' with the path to your .npy file
file_path = '../resultados_grid_search/Wind/Wind_Shared_Knowledge.npy'
data_wind = np.load(file_path)

# Define column names
columns = ['n_estimators', 'group_size', 'max_depth', 'initial_max_depth', 'MSE']

# Create a DataFrame
df_wind = pd.DataFrame(data_wind, columns=columns)

# %%
sorted_df_wind = df_wind.sort_values(by='MSE', ascending=True)

top_50_wind = sorted_df_wind[:50]
top_50_wind
# Out:
#       n_estimators  group_size  max_depth  initial_max_depth        MSE
# 396          280.0         7.0       41.0               14.0  18.128765
# 959          100.0        25.0       15.0               14.0  18.135931
# 1211         150.0         3.0       29.0               14.0  18.145218
# 1256          90.0         3.0       20.0               14.0  18.147263
# 1288         450.0         6.0       39.0               14.0  18.158802
# 1081         100.0        20.0       21.0               14.0  18.159435
# 1493         100.0        25.0       44.0               14.0  18.160389
# 427          300.0        20.0       18.0               14.0  18.161926
# 457          700.0         4.0       48.0               13.0  18.162443
# 818          120.0        10.0       30.0               14.0  18.162645
# 800          280.0         4.0       17.0               13.0  18.162683
# 123          280.0         8.0       18.0               14.0  18.164282
# 1129         280.0         5.0       39.0               14.0  18.164482
# 529          240.0         4.0       13.0               12.0  18.164509
# 501          300.0         6.0       27.0               14.0  18.167040
# 669          600.0         8.0       45.0               14.0  18.168535
# 1020         100.0         5.0       38.0               14.0  18.169466
# 890          900.0         3.0       18.0               14.0  18.169775
# 206          120.0        10.0       21.0               14.0  18.170109
# 489          270.0         3.0       23.0               12.0  18.170317
# 331          700.0         5.0       38.0               13.0  18.170387
# 1137         160.0        40.0       36.0               14.0  18.170626
# 1181          80.0        10.0       39.0               14.0  18.171558
# 128          300.0         3.0       23.0               14.0  18.172289
# 160           80.0        20.0       26.0               13.0  18.172548
# 1208         270.0        45.0       30.0               14.0  18.172928
# 334           80.0        20.0       41.0               13.0  18.173889
# 1183         550.0         5.0       15.0               13.0  18.174122
# 642          650.0        10.0       23.0               14.0  18.174732
# 864          750.0         3.0       35.0               13.0  18.174875
# 657          120.0         4.0       39.0               14.0  18.176132
# 1141         600.0        10.0       32.0               14.0  18.176949
# 979          300.0        15.0       47.0               14.0  18.177458
# 154          260.0         5.0       41.0               14.0  18.177498
# 631           90.0        45.0       42.0               14.0  18.178026
# 114          500.0         5.0       23.0               13.0  18.178406
# 1219         950.0        10.0       37.0               14.0  18.178717
# 467          500.0        20.0       47.0               13.0  18.180651
# 633          140.0         7.0       35.0               14.0  18.180925
# 48           900.0         4.0       28.0               13.0  18.181190
# 1007         700.0        10.0       19.0               13.0  18.181513
# 692          650.0        10.0       16.0               13.0  18.181690
# 1380         500.0        10.0       23.0               13.0  18.182262
# 827          120.0        15.0       23.0               14.0  18.182602
# 551          850.0         5.0       28.0               13.0  18.183073
# 1373         900.0         4.0       26.0               13.0  18.183981
# 44           250.0         5.0       33.0               14.0  18.184471
# 629          110.0         5.0       33.0               14.0  18.184946
# 1462         600.0         3.0       39.0               14.0  18.185102
# 20           700.0        25.0       46.0               13.0  18.185213

# %% [markdown]
# ## Dataset Carbon Emission

# %%
file_path = '../resultados_grid_search/Carbon_Emission/Carbon_Emission_Shared_Knowledge.npy'
data_carbon = np.load(file_path)

# Define column names
columns = ['n_estimators', 'group_size', 'max_depth', 'initial_max_depth', 'MSE']

# Create a DataFrame
df_carbon = pd.DataFrame(data_carbon, columns=columns)

# %%
sorted_df_carbon = df_carbon.sort_values(by='MSE', ascending=True)

top_50_carbon = sorted_df_carbon[:50]
top_50_carbon
# Out:
#       n_estimators  group_size  max_depth  initial_max_depth            MSE
# 549          180.0        45.0       32.0               10.0  259915.921875
# 1046         180.0         4.0       42.0                3.0  260401.140625
# 96           160.0         4.0       26.0                3.0  260525.031250
# 636          160.0         5.0       48.0               10.0  260700.515625
# 620          180.0         6.0       24.0               14.0  260717.187500
# 407          170.0        10.0       20.0               10.0  260746.484375
# 753          180.0        20.0       16.0               10.0  260869.937500
# 614          180.0        15.0       32.0               10.0  260967.359375
# 237          180.0         5.0       41.0               10.0  260974.796875
# 1007         150.0         5.0       20.0               11.0  261021.109375
# 692          250.0        50.0       50.0               11.0  261089.500000
# 1041         210.0         7.0       21.0               10.0  261129.687500
# 1499         160.0         8.0       41.0               10.0  261132.250000
# 299          180.0         6.0       17.0               14.0  261146.687500
# 972          160.0         5.0       29.0               14.0  261154.156250
# 1483         220.0         4.0       44.0                3.0  261245.312500
# 240          160.0        10.0       24.0               14.0  261337.875000
# 506          200.0         4.0       24.0                3.0  261345.125000
# 723          190.0         5.0       49.0               11.0  261353.015625
# 54           160.0        10.0       47.0               14.0  261388.171875
# 208          150.0         5.0       43.0               10.0  261390.859375
# 519          180.0        30.0       48.0                3.0  261416.781250
# 619          160.0        20.0       38.0               10.0  261420.890625
# 1077         200.0         8.0       17.0               14.0  261446.265625
# 526          160.0         8.0       43.0               12.0  261463.796875
# 234          220.0         5.0       29.0               11.0  261488.359375
# 870          240.0         3.0       28.0               14.0  261505.546875
# 416          180.0        15.0       45.0                3.0  261506.125000
# 1071         200.0        50.0       25.0               14.0  261522.578125
# 727          200.0        50.0       33.0               14.0  261522.578125
# 739          180.0        20.0       36.0               10.0  261532.656250
# 749          240.0         5.0       48.0               11.0  261535.937500
# 1190         150.0         6.0       47.0               10.0  261540.296875
# 127          180.0         9.0       32.0               12.0  261541.765625
# 918          180.0         9.0       47.0               12.0  261541.765625
# 13           200.0        50.0       47.0               11.0  261542.484375
# 189          240.0         8.0       18.0               14.0  261550.343750
# 1142         150.0        50.0       40.0               14.0  261556.546875
# 499          240.0        40.0       16.0                2.0  261563.875000
# 1365         250.0        25.0       38.0               11.0  261599.390625
# 1211         140.0         7.0       30.0               10.0  261599.640625
# 247          190.0         5.0       31.0               14.0  261617.531250
# 963          140.0        20.0       19.0               12.0  261636.015625
# 732          250.0         5.0       20.0               14.0  261636.015625
# 917          150.0        25.0       33.0               10.0  261646.671875
# 1196         160.0        40.0       17.0               11.0  261650.265625
# 999          160.0        20.0       41.0               11.0  261664.312500
# 1106         450.0        45.0       33.0                9.0  261700.687500
# 244          140.0         7.0       25.0               14.0  261702.765625
# 180          240.0        30.0       29.0               14.0  261702.984375

# %% [markdown]
# ## House 8L

# %%
file_path = '../resultados_grid_search/House_8L/House_8L_Shared_Knowledge.npy'
data_house_8L = np.load(file_path)

# Define column names
columns = ['n_estimators', 'group_size', 'max_depth', 'initial_max_depth', 'MSE']

# Create a DataFrame
df_house_8L = pd.DataFrame(data_house_8L, columns=columns)

# %%
sorted_df_house_8L = df_house_8L.sort_values(by='MSE', ascending=True)

top_50_house_8L = sorted_df_house_8L[:50]
top_50_house_8L
# Out:
#       n_estimators  group_size  max_depth  initial_max_depth          MSE
# 523          100.0        25.0       49.0                5.0  940004672.0
# 868          350.0         7.0       43.0                6.0  943021888.0
# 159          350.0         7.0       37.0                6.0  943021888.0
# 874          140.0         7.0       19.0                7.0  943955904.0
# 929          250.0         5.0       16.0                8.0  944927104.0
# 153          500.0        10.0       19.0                6.0  945305216.0
# 950          120.0        40.0       40.0                5.0  945462016.0
# 804           70.0        10.0       47.0                3.0  945578048.0
# 435          240.0         8.0       48.0                6.0  945862848.0
# 5            100.0        25.0       25.0                5.0  946311104.0
# 808          700.0         4.0       41.0                6.0  946652032.0
# 68           120.0         6.0       39.0                6.0  947405376.0
# 832           90.0        15.0       42.0               10.0  947500608.0
# 261          800.0         8.0       40.0                6.0  947531520.0
# 708           70.0        35.0       46.0                3.0  947614272.0
# 735          700.0        10.0       43.0                6.0  947740224.0
# 6            700.0        10.0       50.0                6.0  947740224.0
# 1294         140.0        20.0       34.0                6.0  947761216.0
# 427          900.0         4.0       41.0                6.0  947863424.0
# 1003         900.0         4.0       42.0                6.0  947863424.0
# 652           80.0         8.0       41.0                5.0  947943936.0
# 13           400.0        10.0       44.0                6.0  948179008.0
# 1235         250.0         5.0       21.0                8.0  948250752.0
# 921          280.0         8.0       33.0                5.0  948300096.0
# 286          700.0        20.0       41.0                5.0  948304064.0
# 671          750.0         5.0       35.0                6.0  948350016.0
# 1173         290.0         5.0       20.0                8.0  948489600.0
# 1426         850.0        10.0       30.0                6.0  948551040.0
# 310          240.0         4.0       41.0                2.0  948593024.0
# 1484         240.0         4.0       42.0                2.0  948593024.0
# 355          270.0        15.0       21.0                6.0  948593856.0
# 222          700.0        20.0       35.0                5.0  948651072.0
# 916          700.0         4.0       30.0                5.0  948677248.0
# 147          120.0        20.0       18.0                5.0  948727296.0
# 840          110.0        10.0       43.0                3.0  948811328.0
# 736          500.0        10.0       31.0                6.0  948875200.0
# 202          600.0        10.0       44.0                6.0  948967424.0
# 607          600.0         6.0       33.0                6.0  949025664.0
# 328          750.0         6.0       46.0                6.0  949036224.0
# 685          270.0         6.0       32.0                6.0  949085568.0
# 1158         120.0         6.0       17.0                3.0  949102784.0
# 895         1000.0        10.0       18.0                6.0  949251648.0
# 585          500.0        10.0       42.0                6.0  949320768.0
# 459          210.0         6.0       39.0                6.0  949413248.0
# 279          700.0         4.0       42.0                5.0  949477568.0
# 1461         100.0        20.0       29.0                5.0  949537472.0
# 73           270.0         5.0       18.0                3.0  949554688.0
# 345          350.0        25.0       25.0               14.0  949576320.0
# 43           200.0         8.0       44.0                6.0  949610112.0
# 33           550.0        10.0       22.0                6.0  949980096.0

# %%
# Drop the 'MSE' column from each top_50 DataFrame
top_50_wind_dropped = top_50_wind.drop(columns=['MSE'])
top_50_carbon_dropped = top_50_carbon.drop(columns=['MSE'])
top_50_house_8L_dropped = top_50_house_8L.drop(columns=['MSE'])

# Concatenate the DataFrames
concatenated_df = pd.concat([top_50_carbon_dropped, top_50_house_8L_dropped, top_50_wind_dropped], ignore_index=True)

# Drop repeated rows
concatenated_df = concatenated_df.drop_duplicates()

# Convert all values to integers
concatenated_df = concatenated_df.astype(int)

# Save the concatenated DataFrame to a CSV file
concatenated_df.to_csv('csvs/Shared_Knowledge_Top_150.csv', index=False)

# %% [markdown]
# # Top 150

# %%
file_path = '../resultados_top_150/Wind/Wind_Shared_Knowledge_150.npy'
data_wind = np.load(file_path)

# Define column names
columns = ['n_estimators', 'group_size', 'max_depth', 'initial_max_depth', 'MSE']

df_wind_150 = pd.DataFrame(data_wind, columns=columns)

sorted_df_wind_150 = df_wind_150.sort_values(by='MSE', ascending=True)

# Add rank column
sorted_df_wind_150['rank'] = sorted_df_wind_150['MSE'].rank(method='min')

sorted_df_wind_150[:50]
# Out:
#      n_estimators  group_size  max_depth  initial_max_depth        MSE  rank
# 100         280.0         7.0       41.0               14.0  18.128765   1.0
# 101         100.0        25.0       15.0               14.0  18.135931   2.0
# 102         150.0         3.0       29.0               14.0  18.145218   3.0
# 103          90.0         3.0       20.0               14.0  18.147263   4.0
# 104         450.0         6.0       39.0               14.0  18.158802   5.0
# 105         100.0        20.0       21.0               14.0  18.159435   6.0
# 106         100.0        25.0       44.0               14.0  18.160389   7.0
# 107         300.0        20.0       18.0               14.0  18.161926   8.0
# 108         700.0         4.0       48.0               13.0  18.162443   9.0
# 109         120.0        10.0       30.0               14.0  18.162645  10.0
# 110         280.0         4.0       17.0               13.0  18.162683  11.0
# 111         280.0         8.0       18.0               14.0  18.164282  12.0
# 112         280.0         5.0       39.0               14.0  18.164482  13.0
# 113         240.0         4.0       13.0               12.0  18.164509  14.0
# 37          150.0        50.0       40.0               14.0  18.166794  15.0
# 19          160.0        10.0       47.0               14.0  18.166969  16.0
# 114         300.0         6.0       27.0               14.0  18.167040  17.0
# 115         600.0         8.0       45.0               14.0  18.168535  18.0
# 116         100.0         5.0       38.0               14.0  18.169466  19.0
# 117         900.0         3.0       18.0               14.0  18.169775  20.0
# 118         120.0        10.0       21.0               14.0  18.170109  21.0
# 119         270.0         3.0       23.0               12.0  18.170317  22.0
# 120         700.0         5.0       38.0               13.0  18.170387  23.0
# 16          160.0        10.0       24.0               14.0  18.170418  24.0
# 121         160.0        40.0       36.0               14.0  18.170626  25.0
# 122          80.0        10.0       39.0               14.0  18.171558  26.0
# 123         300.0         3.0       23.0               14.0  18.172289  27.0
# 124          80.0        20.0       26.0               13.0  18.172548  28.0
# 125         270.0        45.0       30.0               14.0  18.172928  29.0
# 126          80.0        20.0       41.0               13.0  18.173889  30.0
# 127         550.0         5.0       15.0               13.0  18.174122  31.0
# 128         650.0        10.0       23.0               14.0  18.174732  32.0
# 129         750.0         3.0       35.0               13.0  18.174875  33.0
# 130         120.0         4.0       39.0               14.0  18.176132  34.0
# 131         600.0        10.0       32.0               14.0  18.176949  35.0
# 132         300.0        15.0       47.0               14.0  18.177458  36.0
# 133         260.0         5.0       41.0               14.0  18.177498  37.0
# 134          90.0        45.0       42.0               14.0  18.178026  38.0
# 135         500.0         5.0       23.0               13.0  18.178406  39.0
# 48          140.0         7.0       25.0               14.0  18.178625  40.0
# 136         950.0        10.0       37.0               14.0  18.178717  41.0
# 137         500.0        20.0       47.0               13.0  18.180651  42.0
# 138         140.0         7.0       35.0               14.0  18.180925  43.0
# 139         900.0         4.0       28.0               13.0  18.181190  44.0
# 140         700.0        10.0       19.0               13.0  18.181513  45.0
# 141         650.0        10.0       16.0               13.0  18.181690  46.0
# 142         500.0        10.0       23.0               13.0  18.182262  47.0
# 143         120.0        15.0       23.0               14.0  18.182602  48.0
# 144         850.0         5.0       28.0               13.0  18.183073  49.0
# 145         900.0         4.0       26.0               13.0  18.183981  50.0

# %%
file_path = '../resultados_top_150/House_8L/House_8L_Shared_Knowledge_150.npy'
data_house = np.load(file_path)

# Define column names
columns = ['n_estimators', 'group_size', 'max_depth', 'inital_max_depth', 'MSE']

df_house_150 = pd.DataFrame(data_house, columns=columns)

sorted_df_house_150 = df_house_150.sort_values(by='MSE', ascending=True)

# Add rank column
sorted_df_house_150['rank'] = sorted_df_house_150['MSE'].rank(method='min')

sorted_df_house_150[:50]
# Out:
#      n_estimators  group_size  max_depth  inital_max_depth          MSE  rank
# 50          100.0        25.0       49.0               5.0  940004672.0   1.0
# 51          350.0         7.0       43.0               6.0  943021888.0   2.0
# 52          350.0         7.0       37.0               6.0  943021888.0   2.0
# 53          140.0         7.0       19.0               7.0  943955904.0   4.0
# 54          250.0         5.0       16.0               8.0  944927104.0   5.0
# 55          500.0        10.0       19.0               6.0  945305216.0   6.0
# 56          120.0        40.0       40.0               5.0  945462016.0   7.0
# 57           70.0        10.0       47.0               3.0  945578048.0   8.0
# 58          240.0         8.0       48.0               6.0  945862848.0   9.0
# 59          100.0        25.0       25.0               5.0  946311104.0  10.0
# 60          700.0         4.0       41.0               6.0  946652032.0  11.0
# 61          120.0         6.0       39.0               6.0  947405376.0  12.0
# 62           90.0        15.0       42.0              10.0  947500608.0  13.0
# 63          800.0         8.0       40.0               6.0  947531520.0  14.0
# 64           70.0        35.0       46.0               3.0  947614272.0  15.0
# 65          700.0        10.0       43.0               6.0  947740224.0  16.0
# 66          700.0        10.0       50.0               6.0  947740224.0  16.0
# 67          140.0        20.0       34.0               6.0  947761216.0  18.0
# 69          900.0         4.0       42.0               6.0  947863424.0  19.0
# 68          900.0         4.0       41.0               6.0  947863424.0  19.0
# 70           80.0         8.0       41.0               5.0  947943936.0  21.0
# 71          400.0        10.0       44.0               6.0  948179008.0  22.0
# 72          250.0         5.0       21.0               8.0  948250752.0  23.0
# 73          280.0         8.0       33.0               5.0  948300096.0  24.0
# 74          700.0        20.0       41.0               5.0  948304064.0  25.0
# 75          750.0         5.0       35.0               6.0  948350016.0  26.0
# 76          290.0         5.0       20.0               8.0  948489600.0  27.0
# 77          850.0        10.0       30.0               6.0  948551040.0  28.0
# 79          240.0         4.0       42.0               2.0  948593024.0  29.0
# 78          240.0         4.0       41.0               2.0  948593024.0  29.0
# 80          270.0        15.0       21.0               6.0  948593856.0  31.0
# 81          700.0        20.0       35.0               5.0  948651072.0  32.0
# 82          700.0         4.0       30.0               5.0  948677248.0  33.0
# 83          120.0        20.0       18.0               5.0  948727296.0  34.0
# 84          110.0        10.0       43.0               3.0  948811328.0  35.0
# 85          500.0        10.0       31.0               6.0  948875200.0  36.0
# 86          600.0        10.0       44.0               6.0  948967424.0  37.0
# 87          600.0         6.0       33.0               6.0  949025664.0  38.0
# 88          750.0         6.0       46.0               6.0  949036224.0  39.0
# 89          270.0         6.0       32.0               6.0  949085568.0  40.0
# 90          120.0         6.0       17.0               3.0  949102784.0  41.0
# 91         1000.0        10.0       18.0               6.0  949251648.0  42.0
# 92          500.0        10.0       42.0               6.0  949320768.0  43.0
# 93          210.0         6.0       39.0               6.0  949413248.0  44.0
# 94          700.0         4.0       42.0               5.0  949477568.0  45.0
# 95          100.0        20.0       29.0               5.0  949537472.0  46.0
# 96          270.0         5.0       18.0               3.0  949554688.0  47.0
# 97          350.0        25.0       25.0              14.0  949576320.0  48.0
# 100         280.0         7.0       41.0              14.0  949577216.0  49.0
# 98          200.0         8.0       44.0               6.0  949610112.0  50.0

# %%
file_path = '../resultados_top_150/Carbon_Emission/Carbon_Emission_Shared_Knowledge_150.npy'
data_carbon = np.load(file_path)

# Define column names
columns = ['n_estimators', 'group_size', 'max_depth', 'initial_max_depth', 'MSE']

df_carbon_150 = pd.DataFrame(data_carbon, columns=columns)

sorted_df_carbon_150 = df_carbon_150.sort_values(by='MSE', ascending=True)

# Add rank column
sorted_df_carbon_150['rank'] = sorted_df_carbon_150['MSE'].rank(method='min')

sorted_df_carbon_150[:50]
# Out:
#      n_estimators  group_size  max_depth  initial_max_depth            MSE  \
# 0           180.0        45.0       32.0               10.0  259915.921875
# 1           180.0         4.0       42.0                3.0  260401.140625
# 2           160.0         4.0       26.0                3.0  260525.031250
# 3           160.0         5.0       48.0               10.0  260700.515625
# 4           180.0         6.0       24.0               14.0  260717.187500
# 5           170.0        10.0       20.0               10.0  260746.484375
# 6           180.0        20.0       16.0               10.0  260869.937500
# 7           180.0        15.0       32.0               10.0  260967.359375
# 8           180.0         5.0       41.0               10.0  260974.796875
# 9           150.0         5.0       20.0               11.0  261021.109375
# 10          250.0        50.0       50.0               11.0  261089.500000
# 121         160.0        40.0       36.0               14.0  261129.500000
# 11          210.0         7.0       21.0               10.0  261129.687500
# 12          160.0         8.0       41.0               10.0  261132.250000
# 13          180.0         6.0       17.0               14.0  261146.687500
# 14          160.0         5.0       29.0               14.0  261154.156250
# 15          220.0         4.0       44.0                3.0  261245.312500
# 16          160.0        10.0       24.0               14.0  261337.875000
# 17          200.0         4.0       24.0                3.0  261345.125000
# 102         150.0         3.0       29.0               14.0  261350.921875
# 18          190.0         5.0       49.0               11.0  261353.015625
# 19          160.0        10.0       47.0               14.0  261388.171875
# 20          150.0         5.0       43.0               10.0  261390.859375
# 21          180.0        30.0       48.0                3.0  261416.781250
# 22          160.0        20.0       38.0               10.0  261420.890625
# 23          200.0         8.0       17.0               14.0  261446.265625
# 24          160.0         8.0       43.0               12.0  261463.796875
# 25          220.0         5.0       29.0               11.0  261488.359375
# 26          240.0         3.0       28.0               14.0  261505.546875
# 27          180.0        15.0       45.0                3.0  261506.125000
# 28          200.0        50.0       25.0               14.0  261522.578125
# 29          200.0        50.0       33.0               14.0  261522.578125
# 30          180.0        20.0       36.0               10.0  261532.656250
# 31          240.0         5.0       48.0               11.0  261535.937500
# 72          250.0         5.0       21.0                8.0  261536.718750
# 32          150.0         6.0       47.0               10.0  261540.296875
# 34          180.0         9.0       47.0               12.0  261541.765625
# 33          180.0         9.0       32.0               12.0  261541.765625
# 35          200.0        50.0       47.0               11.0  261542.484375
# 36          240.0         8.0       18.0               14.0  261550.343750
# 37          150.0        50.0       40.0               14.0  261556.546875
# 38          240.0        40.0       16.0                2.0  261563.875000
# 39          250.0        25.0       38.0               11.0  261599.390625
# 40          140.0         7.0       30.0               10.0  261599.640625
# 41          190.0         5.0       31.0               14.0  261617.531250
# 42          140.0        20.0       19.0               12.0  261636.015625
# 43          250.0         5.0       20.0               14.0  261636.015625
# 44          150.0        25.0       33.0               10.0  261646.671875
# 45          160.0        40.0       17.0               11.0  261650.265625
# 46          160.0        20.0       41.0               11.0  261664.312500
#
#      rank
# 0     1.0
# 1     2.0
# 2     3.0
# 3     4.0
# 4     5.0
# 5     6.0
# 6     7.0
# 7     8.0
# 8     9.0
# 9    10.0
# 10   11.0
# 121  12.0
# 11   13.0
# 12   14.0
# 13   15.0
# 14   16.0
# 15   17.0
# 16   18.0
# 17   19.0
# 102  20.0
# 18   21.0
# 19   22.0
# 20   23.0
# 21   24.0
# 22   25.0
# 23   26.0
# 24   27.0
# 25   28.0
# 26   29.0
# 27   30.0
# 28   31.0
# 29   31.0
# 30   33.0
# 31   34.0
# 72   35.0
# 32   36.0
# 34   37.0
# 33   37.0
# 35   39.0
# 36   40.0
# 37   41.0
# 38   42.0
# 39   43.0
# 40   44.0
# 41   45.0
# 42   46.0
# 43   46.0
# 44   48.0
# 45   49.0
# 46   50.0

# %%
filtered_df_house_150 = sorted_df_house_150[(sorted_df_house_150['group_size'] == 7)]
filtered_df_house_150
# Out:
#      n_estimators  group_size  max_depth  inital_max_depth          MSE   rank
# 51          350.0         7.0       43.0               6.0  943021888.0    2.0
# 52          350.0         7.0       37.0               6.0  943021888.0    2.0
# 53          140.0         7.0       19.0               7.0  943955904.0    4.0
# 100         280.0         7.0       41.0              14.0  949577216.0   49.0
# 138         140.0         7.0       35.0              14.0  958135680.0  107.0
# 11          210.0         7.0       21.0              10.0  959047744.0  117.0
# 48          140.0         7.0       25.0              14.0  959420224.0  121.0
# 40          140.0         7.0       30.0              10.0  962094336.0  133.0

# %%
filtered_df_carbon_150 = sorted_df_carbon_150[(sorted_df_carbon_150['group_size'] == 7)]
filtered_df_carbon_150
# Out:
#      n_estimators  group_size  max_depth  initial_max_depth            MSE  \
# 11          210.0         7.0       21.0               10.0  261129.687500
# 40          140.0         7.0       30.0               10.0  261599.640625
# 48          140.0         7.0       25.0               14.0  261702.765625
# 138         140.0         7.0       35.0               14.0  261702.765625
# 100         280.0         7.0       41.0               14.0  262080.843750
# 51          350.0         7.0       43.0                6.0  265299.156250
# 52          350.0         7.0       37.0                6.0  265299.156250
# 53          140.0         7.0       19.0                7.0  265699.593750
#
#       rank
# 11    13.0
# 40    44.0
# 48    52.0
# 138   52.0
# 100   59.0
# 51   111.0
# 52   111.0
# 53   120.0

# %%
filtered_df_wind_150 = sorted_df_wind_150[(sorted_df_wind_150['group_size'] == 7)]
filtered_df_wind_150
# Out:
#      n_estimators  group_size  max_depth  initial_max_depth        MSE   rank
# 100         280.0         7.0       41.0               14.0  18.128765    1.0
# 48          140.0         7.0       25.0               14.0  18.178625   40.0
# 138         140.0         7.0       35.0               14.0  18.180925   43.0
# 40          140.0         7.0       30.0               10.0  18.708132  103.0
# 11          210.0         7.0       21.0               10.0  18.793972  115.0
# 51          350.0         7.0       43.0                6.0  19.011213  132.0
# 52          350.0         7.0       37.0                6.0  19.011213  132.0
# 53          140.0         7.0       19.0                7.0  19.015394  136.0
